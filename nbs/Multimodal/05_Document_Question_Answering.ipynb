# %% [markdown]
# # Document Question Answering
#
# > Placeholder for Document Question Answering (Multimodal) notes and experiments.
#
# - skip_showdoc: true
# - skip_exec: true

# %% [markdown]
# ## Overview
#
# TODO
#
# ---
