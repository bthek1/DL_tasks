# %% [markdown]
# # Image-Text-to-Text
#
# > Placeholder for Image-Text-to-Text (Multimodal) notes and experiments.
#
# - skip_showdoc: true
# - skip_exec: true

# %% [markdown]
# ## Overview
#
# TODO
#
# ---
